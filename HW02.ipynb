# %%
import numpy as np

# %%
import pandas as pd
import pickle as pkl

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LogisticRegression

# %%
from scipy.stats import spearmanr, kendalltau

# %% [markdown]
# Для начала прочитаем и, для более простого анализа, преобразуем исходные данные в `pandas.DataFrame`.

# %% [markdown]
# ## Игроки

# %%
players_df = pd.DataFrame().from_dict(pkl.load(open('players.pkl', 'rb'))).T
players_df.sample(4)
# Out:
#             id     name patronymic      surname
# 63678    63678    Антон   Олегович     Минашкин
# 45549    45549  Дмитрий                 Новиков
# 161753  161753   Фазиль                  Бабаев
# 107765  107765  Дмитрий             Седельников

# %% [markdown]
# Как видно, таблица `players` содержит только информацию об идентификаторе, имени, отчестве (если имеется) и фамилии игрока. В дальнейшем, думается, можно будет использовать ID игрока во избежание полного совпадения ФИО.

# %% [markdown]
# ## Турниры

# %%
tournaments_df = pd.DataFrame().from_dict(pkl.load(open('tournaments.pkl', 'rb'))).T
tournaments_df.sample(4)
# Out:
#         id                                               name  \
# 2213  2213                                       Кубок ДоДона
# 654    654                                 Чемпионат Мордовии
# 6188  6188  Пятая актава: Тропік Казярога. Ліга нацый: Бел...
# 2890  2890                                Чемпионат Финляндии
#
#                       dateStart                    dateEnd  \
# 2213  2013-01-27T00:00:00+04:00  2013-01-27T00:00:00+04:00
# 654   2009-10-01T00:00:00+04:00  2010-05-30T00:00:00+04:00
# 6188  2020-01-09T18:00:00+03:00  2020-01-15T22:00:00+03:00
# 2890  2014-05-10T00:00:00+04:00  2014-05-10T00:00:00+04:00
#
#                               type       season  \
# 2213  {'id': 2, 'name': 'Обычный'}  /seasons/44
# 654   {'id': 2, 'name': 'Обычный'}   /seasons/9
# 6188  {'id': 3, 'name': 'Синхрон'}  /seasons/53
# 2890  {'id': 2, 'name': 'Обычный'}  /seasons/45
#
#                                            orgcommittee  \
# 2213                                                 []
# 654                                                  []
# 6188  [{'id': 108971, 'name': 'Юлия', 'patronymic': ...
# 2890  [{'id': 5720, 'name': 'Иван', 'patronymic': 'В...
#
#                                               synchData  \
# 2213                                               None
# 654                                                None
# 6188  {'dateRequestsAllowedTo': '2020-01-15T20:00:00...
# 2890                                               None
#
#                                questionQty
# 2213  {'1': 15, '2': 15, '3': 15, '4': 15}
# 654                                   None
# 6188           {'1': 12, '2': 12, '3': 12}
# 2890           {'1': 15, '2': 15, '3': 15}

# %% [markdown]
# Информация о турнирах содержит данные об ID турнира и его названии, датах проведения. Есть какая-то информация о количестве вопросов (колонка `questionQty`); это можно будет провалидировать позднее.

# %% [markdown]
# ## Результаты

# %% [markdown]
# Прочитать напрямую в `pandas.DataFrame` этот словарь не удалось, поскольку значения имеют разную длину. Для этого прочитаем данные по каждому ключу отдельно (не забыв сохранить этот ключ, так как по нему, судя по всему, необходимо будет производить слияние с таблицей турниров).

# %%
results = pkl.load(open('results.pkl', 'rb'))
df_list = []
for key, result in results.items():
    df_temp = pd.DataFrame().from_dict(result)
    df_temp['id'] = key
    df_list.append(df_temp)
results_df = pd.concat(df_list, ignore_index=True, sort=False)

# %%
results_df.sample(3)
# Out:
#                                                      team  \
# 356341  {'id': 49832, 'name': 'Судьба робота-собаки', ...
# 152677  {'id': 42178, 'name': 'Неопровержимые улитки',...
# 323053  {'id': 43516, 'name': 'Запасная хромосома', 't...
#
#                                         mask  \
# 356341  011111000111111100100111110101011001
# 152677  010100010101000110000011001100111000
# 323053  011000000000001000010000100100100000
#
#                                                   current  questionsTotal  \
# 356341  {'name': 'Калi капiтан - пацук', 'town': {'id'...            23.0
# 152677  {'name': 'Неопровержимые улитки', 'town': {'id...            14.0
# 323053  {'name': 'Запасная хромосома', 'town': {'id': ...             7.0
#
#                                              synchRequest  position  \
# 356341  {'id': 40466, 'venue': {'id': 3117, 'name': 'М...      43.5
# 152677  {'id': 8260, 'venue': {'id': 3188, 'name': 'Ве...     202.5
# 323053  {'id': 33397, 'venue': {'id': 3223, 'name': 'А...      98.0
#
#                                            controversials flags  \
# 356341                                                 []    []
# 152677                                                 []    []
# 323053  [{'id': 56139, 'questionNumber': 27, 'answer':...    []
#
#                                               teamMembers    id
# 356341  [{'flag': 'Л', 'usedRating': 13254, 'rating': ...  4663
# 152677  [{'flag': 'К', 'usedRating': 3996, 'rating': 4...  2783
# 323053  [{'flag': 'К', 'usedRating': 1585, 'rating': 1...  4354

# %% [markdown]
# Итак, в таблице результатов, помимо прочего, хранится информация о командах, маске (результаты ответа на вопросы), суммарное количество отвеченных вопросов (`questionsTotal`), позиция команды, предположительно данные об апелляциях (`controversials`) и ID турнира, по которому и будет производиться слияние.

# %% [markdown]
# В соответсвии с заданием, оставим только результаты, в которых есть информация об ответах команды и её составе.

# %%
(results_df['teamMembers'].apply(len) == 0).sum()
# Out:
# 29589

# %%
results_df = results_df[(results_df['mask'].notna()) & (results_df['teamMembers'].apply(len) != 0)]

# %% [markdown]
# Перед разделением датасета на тренировочную и тестовую выборки сольём таблицы результатов и турниров.

# %%
final_df = pd.merge(
    results_df,
    tournaments_df,
    on='id'
)

# %%
final_df.sample(3)
# Out:
#                                                      team  \
# 303457  {'id': 44786, 'name': '302-бис', 'town': {'id'...
# 120603  {'id': 46573, 'name': 'Мятый элемент', 'town':...
# 302603  {'id': 63442, 'name': 'Dream Team', 'town': {'...
#
#                                         mask  \
# 303457  101110011100101000110000000100111001
# 120603  000000001100010000000000000000000000
# 302603  010010001001111000100011101000000010
#
#                                                   current  questionsTotal  \
# 303457  {'name': '302-бис', 'town': {'id': 277, 'name'...            16.0
# 120603  {'name': 'Помятый бозон', 'town': {'id': 201, ...             3.0
# 302603  {'name': 'Dream Team', 'town': {'id': 60, 'nam...            13.0
#
#                                              synchRequest  position  \
# 303457  {'id': 51262, 'venue': {'id': 3050, 'name': 'Р...     428.5
# 120603  {'id': 22793, 'venue': {'id': 3117, 'name': 'М...     784.0
# 302603                                               None     610.5
#
#                                            controversials flags  \
# 303457  [{'id': 83547, 'questionNumber': 14, 'answer':...    []
# 120603                                                 []    []
# 302603                                                 []    []
#
#                                               teamMembers    id  \
# 303457  [{'flag': None, 'usedRating': 6958, 'rating': ...  4981
# 120603  [{'flag': 'Б', 'usedRating': 3631, 'rating': 3...  3329
# 302603  [{'flag': 'Л', 'usedRating': 0, 'rating': 0, '...  4976
#
#                                   name                  dateStart  \
# 303457                    ОВСЧ. 1 этап  2018-09-21T20:00:00+03:00
# 120603        Балтийский берег. 5 игра  2016-04-08T19:05:00+03:00
# 302603  Школьный Синхрон-lite. Сезон 1  2017-11-17T18:00:00+03:00
#
#                           dateEnd                              type  \
# 303457  2018-09-25T20:00:00+03:00      {'id': 3, 'name': 'Синхрон'}
# 120603  2016-04-12T19:00:00+03:00      {'id': 3, 'name': 'Синхрон'}
# 302603  2018-04-30T19:55:00+03:00  {'id': 5, 'name': 'Общий зачёт'}
#
#              season                                       orgcommittee  \
# 303457  /seasons/52  [{'id': 505, 'name': 'Иделия', 'patronymic': '...
# 120603  /seasons/49  [{'id': 23030, 'name': 'Марина', 'patronymic':...
# 302603  /seasons/51  [{'id': 23740, 'name': 'Владимир', 'patronymic...
#
#                                                 synchData  \
# 303457  {'dateRequestsAllowedTo': '2018-09-25T23:59:59...
# 120603  {'dateRequestsAllowedTo': '2016-04-10T23:59:59...
# 302603                                               None
#
#                         questionQty
# 303457  {'1': 12, '2': 12, '3': 12}
# 120603  {'1': 12, '2': 12, '3': 12}
# 302603  {'1': 36, '2': 36, '3': 36}

# %% [markdown]
# Необходимые преобразования для колонок с датами:

# %%
for col in ['dateStart', 'dateEnd']:
    final_df[col] = pd.to_datetime(final_df[col], utc=True).dt.tz_localize(None)

# %%
final_df.sample(3)
# Out:
#                                                      team  \
# 344634  {'id': 65626, 'name': 'Привкус победы', 'town'...
# 256440  {'id': 41444, 'name': 'Полёт акваланга', 'town...
# 386832  {'id': 47284, 'name': 'Цианид калия', 'town': ...
#
#                                                      mask  \
# 344634  0110100100001011111101100010001100111111000011...
# 256440               01101011010001X110111110111110110111
# 386832               001100000100110011001110000001001111
#
#                                                   current  questionsTotal  \
# 344634  {'name': 'Привкус победы', 'town': {'id': 197,...            30.0
# 256440  {'name': 'Полёт акваланга', 'town': {'id': 201...            24.0
# 386832  {'name': 'Цианид калия', 'town': {'id': 21, 'n...            15.0
#
#                                              synchRequest  position  \
# 344634                                               None      17.0
# 256440  {'id': 40727, 'venue': {'id': 3117, 'name': 'М...       4.0
# 386832  {'id': 72975, 'venue': {'id': 3737, 'name': 'К...     640.5
#
#                                            controversials  \
# 344634                                                 []
# 256440  [{'id': 67909, 'questionNumber': 18, 'answer':...
# 386832                                                 []
#
#                                                     flags  \
# 344634                                                 []
# 256440                                                 []
# 386832  [{'id': 4, 'shortName': 'С', 'longName': 'Студ...
#
#                                               teamMembers    id  \
# 344634  [{'flag': 'Б', 'usedRating': 3505, 'rating': 3...  5317
# 256440  [{'flag': 'Л', 'usedRating': 10473, 'rating': ...  4494
# 386832  [{'flag': 'Б', 'usedRating': 4393, 'rating': 4...  5752
#
#                             name           dateStart             dateEnd  \
# 344634                 Щит и меч 2018-11-25 07:00:00 2018-11-25 12:00:00
# 256440       Лига Сибири. 3 этап 2017-12-08 16:00:00 2017-12-12 16:00:00
# 386832  Балтийский Берег. 2 игра 2019-11-27 21:01:00 2019-12-04 20:55:00
#
#                                 type       season  \
# 344634  {'id': 2, 'name': 'Обычный'}  /seasons/52
# 256440  {'id': 3, 'name': 'Синхрон'}  /seasons/51
# 386832  {'id': 3, 'name': 'Синхрон'}  /seasons/53
#
#                                              orgcommittee  \
# 344634  [{'id': 4715, 'name': 'Сергей', 'patronymic': ...
# 256440  [{'id': 39218, 'name': 'Владислав', 'patronymi...
# 386832  [{'id': 23030, 'name': 'Марина', 'patronymic':...
#
#                                                 synchData  \
# 344634                                               None
# 256440  {'dateRequestsAllowedTo': '2017-12-12T23:59:59...
# 386832  {'dateRequestsAllowedTo': '2019-12-04T19:00:00...
#
#                                  questionQty
# 344634  {'1': 15, '2': 15, '3': 15, '4': 15}
# 256440           {'1': 12, '2': 12, '3': 12}
# 386832           {'1': 12, '2': 12, '3': 12}

# %% [markdown]
# ## Преобразования

# %% [markdown]
# Создадим колонку, в которой соберём ID игроков соответствующей команды.

# %%
final_df['playerIDs'] = final_df['teamMembers'].apply(lambda x: [player['player']['id'] for player in x])

# %%
final_df['team.id'] = final_df['team'].apply(lambda x: x.get('id', None))

# %%
final_df.sample(4)
# Out:
#                                                      team  \
# 164554  {'id': 48807, 'name': 'Лаванда', 'town': {'id'...
# 179821  {'id': 4228, 'name': 'Выпь', 'town': {'id': 27...
# 434664  {'id': 74645, 'name': 'Молито', 'town': {'id':...
# 225011  {'id': 58315, 'name': 'Оливковая эйфория', 'to...
#
#                                                  mask  \
# 164554  000010000100100001100100000001110000000000000
# 179821           011100111101101111101011110111010100
# 434664           000000001001000000001000000000000000
# 225011           001001000000001000000000000000001000
#
#                                                   current  questionsTotal  \
# 164554  {'name': 'Лаванда', 'town': {'id': 161, 'name'...             9.0
# 179821  {'name': 'Выпь', 'town': {'id': 277, 'name': '...            24.0
# 434664  {'name': 'Молито', 'town': {'id': 2163, 'name'...             3.0
# 225011  {'name': 'Оливковая эйфория', 'town': {'id': 2...             4.0
#
#                                              synchRequest  position  \
# 164554                                               None      25.0
# 179821  {'id': 26951, 'venue': {'id': 3050, 'name': 'Р...     101.5
# 434664                                               None     765.0
# 225011                                               None      27.5
#
#        controversials                                              flags  \
# 164554             []  [{'id': 4, 'shortName': 'С', 'longName': 'Студ...
# 179821             []                                                 []
# 434664             []  [{'id': 2, 'shortName': 'МШ', 'longName': 'Мла...
# 225011             []                                                 []
#
#                                               teamMembers    id  \
# 164554  [{'flag': 'К', 'usedRating': 0, 'rating': 0, '...  3748
# 179821  [{'flag': 'Б', 'usedRating': 7320, 'rating': 7...  3867
# 434664  [{'flag': None, 'usedRating': 0, 'rating': 0, ...  6249
# 225011  [{'flag': 'К', 'usedRating': 0, 'rating': 0, '...  4326
#
#                                          name           dateStart  \
# 164554                                  Этажи 2016-04-10 07:00:00
# 179821                           ОВСЧ. 2 этап 2016-10-21 16:00:00
# 434664         Школьный синхрон-lite. Сезон 3 2019-08-31 21:05:00
# 225011  Межфакультетский кубок МГУ. Отбор № 6 2017-04-07 11:00:00
#
#                    dateEnd                              type       season  \
# 164554 2016-04-10 15:00:00      {'id': 2, 'name': 'Обычный'}  /seasons/49
# 179821 2016-10-25 16:00:00      {'id': 3, 'name': 'Синхрон'}  /seasons/50
# 434664 2020-04-30 20:55:00  {'id': 5, 'name': 'Общий зачёт'}  /seasons/53
# 225011 2017-04-07 11:00:00      {'id': 2, 'name': 'Обычный'}  /seasons/50
#
#                                              orgcommittee  \
# 164554  [{'id': 40234, 'name': 'Александр', 'patronymi...
# 179821  [{'id': 505, 'name': 'Иделия', 'patronymic': '...
# 434664  [{'id': 23740, 'name': 'Владимир', 'patronymic...
# 225011  [{'id': 5990, 'name': 'Андрей', 'patronymic': ...
#
#                                                 synchData  \
# 164554                                               None
# 179821  {'dateRequestsAllowedTo': '2016-10-19T23:59:59...
# 434664                                               None
# 225011                                               None
#
#                                               questionQty  \
# 164554                        {'1': 15, '2': 15, '3': 15}
# 179821                        {'1': 12, '2': 12, '3': 12}
# 434664  {'1': 36, '2': 36, '3': 36, '4': 36, '5': 36, ...
# 225011                        {'1': 12, '2': 12, '3': 12}
#
#                                                playerIDs  team.id
# 164554                  [104088, 104089, 105575, 105576]    48807
# 179821          [7231, 133, 40931, 17343, 55585, 128161]     4228
# 434664  [210348, 210349, 210350, 210351, 210352, 210353]    74645
# 225011          [146976, 146977, 146978, 146979, 146980]    58315

# %% [markdown]
# Для ускорения работы и экономии памяти оставим только турниры из 2019 и 2020 годов. Построим таблицу со следующими строками: (ID игрока, ID вопроса, результат)

# %%
short_df = final_df.query('dateStart < "2021" and dateStart >= "2019"')[
    ['mask', 'dateStart', 'id', 'playerIDs', 'team.id']
]

# %%
short_df.sample(3)
# Out:
#                                                      mask           dateStart  \
# 361846            001011010001000100001011011010100010001 2019-04-01 11:00:00
# 316650   111110101011111110101101100100000000000001000010 2019-03-29 16:00:00
# 397327  1000101000110011100100010000001000001110100000... 2019-10-20 09:00:00
#
#           id                                   playerIDs  team.id
# 361846  5545   [31070, 27441, 8896, 71506, 41846, 71507]    41420
# 316650  5025  [37572, 33096, 29805, 36274, 36920, 45344]     3883
# 397327  5795   [24365, 74181, 69503, 8103, 39036, 10774]      575

# %%
short_df['questionIDs'] = None

# %%
short_df['id'] = short_df['id'].astype(str)

# %%
for idx, row in short_df.iterrows():
    short_df.loc[idx, 'questionIDs'] = str(list((row['id']+'_'+str(i), row['mask'][i]) for i in range(len(row['mask']))))

# %%
short_df['questionIDs'] = short_df['questionIDs'].apply(eval)

# %%
short_df.sample(3)
# Out:
#                                         mask           dateStart    id  \
# 432972  111100001010011100100111110100111001 2020-03-05 16:00:00  6218
# 301155  110001000101111011100111111110111110 2019-04-05 16:05:00  4975
# 405523  010001001011000010111001101001001100 2020-02-12 21:00:00  5823
#
#                                           playerIDs  team.id  \
# 432972          [55531, 96325, 5130, 18070, 219893]    50869
# 301155  [92909, 126413, 94793, 61311, 12456, 15501]    51461
# 405523                 [32749, 53524, 93874, 62383]    27477
#
#                                               questionIDs
# 432972  [(6218_0, 1), (6218_1, 1), (6218_2, 1), (6218_...
# 301155  [(4975_0, 1), (4975_1, 1), (4975_2, 0), (4975_...
# 405523  [(5823_0, 0), (5823_1, 1), (5823_2, 0), (5823_...

# %%
short_df = short_df.explode(column='playerIDs', ignore_index=True)

# %%
short_df.sample(4)
# Out:
#                                                      mask           dateStart  \
# 345452               111110101000011011101111011100110010 2020-03-07 13:00:00
# 491250               110100100001100110101001001000010010 2019-11-16 09:00:00
# 93848   1111111101101111111001001110111011100000111101... 2019-02-16 09:30:00
# 106430               010010100001101010100010010100011100 2019-02-14 21:00:00
#
#           id playerIDs  team.id  \
# 345452  5799     25177     4109
# 491250  6071    160662    27656
# 93848   5325      2857     4989
# 106430  5390    165619     8015
#
#                                               questionIDs
# 345452  [(5799_0, 1), (5799_1, 1), (5799_2, 1), (5799_...
# 491250  [(6071_0, 1), (6071_1, 1), (6071_2, 0), (6071_...
# 93848   [(5325_0, 1), (5325_1, 1), (5325_2, 1), (5325_...
# 106430  [(5390_0, 0), (5390_1, 1), (5390_2, 0), (5390_...

# %%
short_df = short_df.explode(column='questionIDs', ignore_index=True)

# %%
short_df['question_result'] = short_df['questionIDs'].str[-1]
short_df['questionID'] = short_df['questionIDs'].str[0]

# %%
short_df.sample(3)
# Out:
#                                                        mask  \
# 5596337                110000110100100000000111010010000000
# 22022146   111101101111111111111110011111011111110011111111
# 5548044   1110100110010010100100011000001101110000110011...
#
#                    dateStart    id playerIDs  team.id   questionIDs  \
# 5596337  2020-04-18 16:00:00  5477    171960    59920  (5477_14, 0)
# 22022146 2020-02-29 08:00:00  6233     69394     4109  (6233_33, 1)
# 5548044  2019-04-13 00:00:00  5475    126814    70713  (5475_87, 0)
#
#          question_result questionID
# 5596337                0    5477_14
# 22022146               1    6233_33
# 5548044                0    5475_87

# %% [markdown]
# ## Разделение данных

# %%
cols_to_leave = ['team.id', 'playerIDs', 'questionID', 'question_result']
train_df = short_df.loc[short_df['dateStart'].dt.year == 2019, cols_to_leave]
test_df = short_df.loc[short_df['dateStart'].dt.year == 2020, cols_to_leave]

# %%
train_df.query('question_result == "X"').head()
# Out:
#         team.id playerIDs questionID question_result
# 619526    69309     27822    4986_23               X
# 619562    69309     28751    4986_23               X
# 619598    69309     30270    4986_23               X
# 619634    69309     33620    4986_23               X
# 619670    69309      2421    4986_23               X

# %%
train_df.sample(3)
# Out:
#           team.id playerIDs questionID question_result
# 17669591    67543    125697    5890_15               0
# 22252574    56369    183736   6249_163               0
# 693329      56373    138370    4986_26               1

# %% [markdown]
# В тренировочной выборке имеются вопросы, отмеченные как `X`. Предположительно, данные вопросы были сняты с турнира. Данное предположение подтверждается, что с помощью `X` отмечены одинаковые вопросы для всех команд. Пример:

# %%
final_df.query("id == 4986")
# Out:
#                                                      team  \
# 307844  {'id': 69309, 'name': 'Брют', 'town': {'id': 2...
# 307845  {'id': 49758, 'name': 'Мимино', 'town': {'id':...
# 307846  {'id': 312, 'name': 'Социал-демократы', 'town'...
# 307847  {'id': 27177, 'name': 'Призраки Коши', 'town':...
# 307848  {'id': 928, 'name': 'ОМ', 'town': {'id': 67, '...
# ...                                                   ...
# 308746  {'id': 69290, 'name': 'Исполкони', 'town': {'i...
# 308747  {'id': 69437, 'name': 'АКМ', 'town': {'id': 16...
# 308748  {'id': 69492, 'name': 'Халва', 'town': {'id': ...
# 308749  {'id': 69493, 'name': 'Чертоги разума', 'town'...
# 308750  {'id': 69526, 'name': 'Айсберг', 'town': {'id'...
#
#                                         mask  \
# 307844  11111111111111110111101X111111111111
# 307845  11111111011111110111111X110111111111
# 307846  11111110011111011111011X111111111111
# 307847  11111110111111011111011X111111101111
# 307848  11111111111111110101011X110101111111
# ...                                      ...
# 308746  00000000000000000000000X000000000000
# 308747  00000000000000000000000X000000000000
# 308748  00000000000000000000000X000000000000
# 308749  00000000000000000000000X000000000000
# 308750  00000000000000000000000X000000000000
#
#                                                   current  questionsTotal  \
# 307844  {'name': 'Брют', 'town': {'id': 201, 'name': '...            33.0
# 307845  {'name': 'Мимино', 'town': {'id': 449, 'name':...            32.0
# 307846  {'name': 'Социал-демократы', 'town': {'id': 20...            31.0
# 307847  {'name': 'Призраки Коши', 'town': {'id': 285, ...            31.0
# 307848  {'name': 'ОМ', 'town': {'id': 67, 'name': 'Вор...            30.0
# ...                                                   ...             ...
# 308746  {'name': 'Исполкони', 'town': {'id': 22, 'name...             0.0
# 308747  {'name': 'АКМ', 'town': {'id': 1693, 'name': '...             0.0
# 308748  {'name': 'Халва', 'town': {'id': 22, 'name': '...             0.0
# 308749  {'name': 'Чертоги разума', 'town': {'id': 22, ...             0.0
# 308750  {'name': 'Айсберг', 'town': {'id': 1863, 'name...             0.0
#
#                                              synchRequest  position  \
# 307844  {'id': 58884, 'venue': {'id': 3117, 'name': 'М...       1.0
# 307845  {'id': 58921, 'venue': {'id': 3117, 'name': 'М...       2.0
# 307846  {'id': 58884, 'venue': {'id': 3117, 'name': 'М...       3.5
# 307847  {'id': 56414, 'venue': {'id': 3030, 'name': 'С...       3.5
# 307848  {'id': 58770, 'venue': {'id': 3065, 'name': 'В...       6.5
# ...                                                   ...       ...
# 308746  {'id': 57006, 'venue': {'id': 3237, 'name': 'Б...     905.5
# 308747  {'id': 58942, 'venue': {'id': 3303, 'name': 'А...     905.5
# 308748  {'id': 57006, 'venue': {'id': 3237, 'name': 'Б...     905.5
# 308749  {'id': 57006, 'venue': {'id': 3237, 'name': 'Б...     905.5
# 308750  {'id': 59025, 'venue': {'id': 3440, 'name': 'П...     905.5
#
#                                            controversials flags  \
# 307844                                                 []    []
# 307845                                                 []    []
# 307846  [{'id': 94154, 'questionNumber': 18, 'answer':...    []
# 307847                                                 []    []
# 307848  [{'id': 94319, 'questionNumber': 23, 'answer':...    []
# ...                                                   ...   ...
# 308746                                                 []    []
# 308747                                                 []    []
# 308748                                                 []    []
# 308749                                                 []    []
# 308750                                                 []    []
#
#                                               teamMembers    id          name  \
# 307844  [{'flag': None, 'usedRating': 14484, 'rating':...  4986  ОВСЧ. 6 этап
# 307845  [{'flag': 'Л', 'usedRating': 12749, 'rating': ...  4986  ОВСЧ. 6 этап
# 307846  [{'flag': 'Л', 'usedRating': 11577, 'rating': ...  4986  ОВСЧ. 6 этап
# 307847  [{'flag': 'Л', 'usedRating': 13667, 'rating': ...  4986  ОВСЧ. 6 этап
# 307848  [{'flag': 'К', 'usedRating': 10074, 'rating': ...  4986  ОВСЧ. 6 этап
# ...                                                   ...   ...           ...
# 308746  [{'flag': 'Б', 'usedRating': 0, 'rating': 0, '...  4986  ОВСЧ. 6 этап
# 308747  [{'flag': 'Л', 'usedRating': 3653, 'rating': 3...  4986  ОВСЧ. 6 этап
# 308748  [{'flag': 'Б', 'usedRating': 0, 'rating': 0, '...  4986  ОВСЧ. 6 этап
# 308749  [{'flag': 'Б', 'usedRating': 0, 'rating': 0, '...  4986  ОВСЧ. 6 этап
# 308750  [{'flag': None, 'usedRating': 0, 'rating': 0, ...  4986  ОВСЧ. 6 этап
#
#                  dateStart             dateEnd                          type  \
# 307844 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 307845 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 307846 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 307847 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 307848 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# ...                    ...                 ...                           ...
# 308746 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 308747 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 308748 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 308749 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
# 308750 2019-02-15 17:00:00 2019-02-19 17:00:00  {'id': 3, 'name': 'Синхрон'}
#
#              season                                       orgcommittee  \
# 307844  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 307845  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 307846  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 307847  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 307848  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# ...             ...                                                ...
# 308746  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 308747  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 308748  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 308749  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
# 308750  /seasons/52  [{'id': 59140, 'name': 'Борис', 'patronymic': ...
#
#                                                 synchData  \
# 307844  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 307845  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 307846  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 307847  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 307848  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# ...                                                   ...
# 308746  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 308747  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 308748  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 308749  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
# 308750  {'dateRequestsAllowedTo': '2019-02-19T23:59:59...
#
#                         questionQty  \
# 307844  {'1': 12, '2': 12, '3': 12}
# 307845  {'1': 12, '2': 12, '3': 12}
# 307846  {'1': 12, '2': 12, '3': 12}
# 307847  {'1': 12, '2': 12, '3': 12}
# 307848  {'1': 12, '2': 12, '3': 12}
# ...                             ...
# 308746  {'1': 12, '2': 12, '3': 12}
# 308747  {'1': 12, '2': 12, '3': 12}
# 308748  {'1': 12, '2': 12, '3': 12}
# 308749  {'1': 12, '2': 12, '3': 12}
# 308750  {'1': 12, '2': 12, '3': 12}
#
#                                                playerIDs  team.id
# 307844                [27822, 28751, 30270, 33620, 2421]    69309
# 307845         [6482, 13782, 33509, 34936, 27240, 36754]    49758
# 307846          [19411, 19599, 25724, 9678, 5894, 32266]      312
# 307847         [6212, 37718, 16837, 33032, 31493, 30371]    27177
# 307848         [5248, 48319, 26101, 82868, 37746, 36910]      928
# ...                                                  ...      ...
# 308746                  [190528, 190529, 191319, 191320]    69290
# 308747                          [157570, 163322, 191115]    69437
# 308748          [191321, 191323, 191324, 191325, 191326]    69492
# 308749                          [191327, 191328, 191329]    69493
# 308750  [191439, 191440, 191441, 191442, 191443, 191444]    69526
#
# [907 rows x 20 columns]

# %% [markdown]
# Таким образом, данные вопросы следует удалить и из тренировочной, и из тестовой выборки.

# %%
final_df.query("id == 5141").sample(10)
# Out:
#                                                      team  \
# 332947  {'id': 48997, 'name': 'Уэллс Фарго', 'town': {...
# 332650  {'id': 1025, 'name': 'Двин', 'town': {'id': 10...
# 332681  {'id': 55501, 'name': 'Семь сорок', 'town': {'...
# 332671  {'id': 46953, 'name': 'Molinos', 'town': {'id'...
# 332611  {'id': 26656, 'name': 'Ни стыда, ни совести', ...
# 332568  {'id': 59580, 'name': 'И остались голодными', ...
# 332869  {'id': 55924, 'name': 'Почему лев царь зверей?...
# 333001  {'id': 58064, 'name': 'Отдел кадров', 'town': ...
# 332954  {'id': 59914, 'name': 'И так сойдёт', 'town': ...
# 332777  {'id': 54475, 'name': 'Сава-Мава', 'town': {'i...
#
#                                                     mask  \
# 332947  1100000010011011010100011001010101X0110010100011
# 332650  1110110110111011100101110100000101X1111011101111
# 332681  1111011110111001110110011111001110X1110010010110
# 332671  1111111110010011100100011101100110X0110111111110
# 332611  1111111000111001110110011111100100X1111111100111
# 332568  1111110111111011110110011111110010X1100010111111
# 332869  1110110100110101100100011111000100X1110010101100
# 333001  0111100000111000100100001001000000X0110011010110
# 332954  1110101100101000100100001111000000X0110111000110
# 332777  1100101100010111100010011110011110X1010111100111
#
#                                                   current  questionsTotal  \
# 332947  {'name': 'Уэллс Фарго', 'town': {'id': 161, 'n...            21.0
# 332650  {'name': 'Двин', 'town': {'id': 100, 'name': '...            31.0
# 332681  {'name': 'Семь сорок', 'town': {'id': 197, 'na...            31.0
# 332671  {'name': 'Molinos', 'town': {'id': 285, 'name'...            31.0
# 332611  {'name': 'Ни стыда, ни совести', 'town': {'id'...            33.0
# 332568  {'name': 'И остались голодными', 'town': {'id'...            35.0
# 332869  {'name': '6 персонажей в поисках Сартра', 'tow...            25.0
# 333001  {'name': 'Отдел кадров', 'town': {'id': 285, '...            18.0
# 332954  {'name': 'И так сойдёт', 'town': {'id': 216, '...            21.0
# 332777  {'name': 'Сава-Мава', 'town': {'id': 201, 'nam...            28.0
#
#                                              synchRequest  position  \
# 332947  {'id': 57408, 'venue': {'id': 3077, 'name': 'К...     447.0
# 332650  {'id': 57308, 'venue': {'id': 3033, 'name': 'Е...     164.0
# 332681  {'id': 57551, 'venue': {'id': 3112, 'name': 'М...     164.0
# 332671  {'id': 56942, 'venue': {'id': 3030, 'name': 'С...     164.0
# 332611  {'id': 57408, 'venue': {'id': 3077, 'name': 'К...     109.5
# 332568  {'id': 57468, 'venue': {'id': 3133, 'name': 'С...      58.5
# 332869  {'id': 57372, 'venue': {'id': 3103, 'name': 'И...     356.5
# 333001  {'id': 56942, 'venue': {'id': 3030, 'name': 'С...     499.0
# 332954  {'id': 57381, 'venue': {'id': 3064, 'name': 'Н...     447.0
# 332777  {'id': 57443, 'venue': {'id': 3117, 'name': 'М...     262.0
#
#                                            controversials flags  \
# 332947  [{'id': 92021, 'questionNumber': 7, 'answer': ...    []
# 332650                                                 []    []
# 332681                                                 []    []
# 332671                                                 []    []
# 332611  [{'id': 92062, 'questionNumber': 32, 'answer':...    []
# 332568                                                 []    []
# 332869                                                 []    []
# 333001  [{'id': 92065, 'questionNumber': 18, 'answer':...    []
# 332954  [{'id': 92150, 'questionNumber': 16, 'answer':...    []
# 332777                                                 []    []
#
#                                               teamMembers    id  \
# 332947  [{'flag': 'К', 'usedRating': 8339, 'rating': 8...  5141
# 332650  [{'flag': 'Б', 'usedRating': 8701, 'rating': 8...  5141
# 332681  [{'flag': 'Б', 'usedRating': 8456, 'rating': 8...  5141
# 332671  [{'flag': 'Б', 'usedRating': 6709, 'rating': 6...  5141
# 332611  [{'flag': 'Б', 'usedRating': 10102, 'rating': ...  5141
# 332568  [{'flag': 'Л', 'usedRating': 11455, 'rating': ...  5141
# 332869  [{'flag': 'Л', 'usedRating': 9965, 'rating': 9...  5141
# 333001  [{'flag': 'Б', 'usedRating': 3803, 'rating': 3...  5141
# 332954  [{'flag': 'К', 'usedRating': 6197, 'rating': 6...  5141
# 332777  [{'flag': 'Б', 'usedRating': 6639, 'rating': 6...  5141
#
#                  name           dateStart             dateEnd  \
# 332947  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332650  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332681  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332671  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332611  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332568  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332869  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 333001  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332954  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
# 332777  Азовский бриз 2019-01-18 16:00:00 2019-01-22 16:00:00
#
#                                 type       season  \
# 332947  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332650  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332681  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332671  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332611  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332568  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332869  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 333001  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332954  {'id': 3, 'name': 'Синхрон'}  /seasons/52
# 332777  {'id': 3, 'name': 'Синхрон'}  /seasons/52
#
#                                              orgcommittee  \
# 332947  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332650  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332681  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332671  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332611  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332568  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332869  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 333001  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332954  [{'id': 15755, 'name': 'Александр', 'patronymi...
# 332777  [{'id': 15755, 'name': 'Александр', 'patronymi...
#
#                                                 synchData  \
# 332947  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332650  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332681  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332671  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332611  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332568  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332869  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 333001  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332954  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
# 332777  {'dateRequestsAllowedTo': '2019-01-22T23:59:59...
#
#                                  questionQty  \
# 332947  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332650  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332681  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332671  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332611  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332568  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332869  {'1': 12, '2': 12, '3': 12, '4': 12}
# 333001  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332954  {'1': 12, '2': 12, '3': 12, '4': 12}
# 332777  {'1': 12, '2': 12, '3': 12, '4': 12}
#
#                                                playerIDs  team.id
# 332947  [118683, 133861, 119947, 110409, 118681, 189514]    48997
# 332650                  [12915, 658, 8118, 19143, 42837]     1025
# 332681                [6284, 29049, 10128, 25875, 10989]    55501
# 332671    [98598, 115148, 98599, 162691, 125018, 134358]    46953
# 332611       [17146, 38047, 88067, 31231, 73295, 101697]    26656
# 332568      [27009, 116628, 105369, 10236, 88505, 54574]    59580
# 332869                    [41623, 135914, 138186, 94923]    55924
# 333001          [145808, 149145, 145806, 178272, 149144]    58064
# 332954                    [27929, 60845, 139599, 144355]    59914
# 332777           [19980, 131315, 131646, 131934, 133364]    54475

# %% [markdown]
# Также стоит удалить записи с `?` в качестве результата. Предполагаю, что это нерешенная апелляция или её незарегистрированный результат.

# %%
train_df['question_result'].unique()
# Out:
# array(['1', '0', 'X', '?'], dtype=object)

# %%
train_df = train_df.query('question_result != "X" and question_result != "?"').astype({'question_result': int})
test_df = test_df.query('question_result != "X" and question_result != "?"').astype({'question_result': int})

# %%
train_df.sample(3)
# Out:
#           team.id playerIDs questionID  question_result
# 6532704     56625    142677     5534_9                0
# 18059111     7567     15466    5920_30                0
# 9288645     67142    118683     5698_3                0

# %% [markdown]
# ## OneHot-кодирование и тренировка baseline-модели

# %%
ohe = OneHotEncoder(handle_unknown='ignore')

# %%
train_ohe = ohe.fit_transform(train_df.drop(columns=['team.id', 'question_result']))

# %%
logreg = LogisticRegression(solver='saga', fit_intercept=True)

# %%
logreg.fit(train_ohe, train_df['question_result'])
# Out:
# LogisticRegression(solver='saga')

# %%
pkl.dump(logreg, open('logreg-fit-intercept.pkl', 'wb'))

# %%
logreg.intercept_
# Out:
# array([-1.63236333])

# %% [markdown]
# В качестве результата возьмем веса натренированной модели.

# %%
weight_df = pd.DataFrame({'id': ohe.categories_[0], 'weight': logreg.coef_[0][:len(ohe.categories_[0])]}).sort_values(by='weight', ascending=False)

# %%
weight_df = pd.merge(weight_df, players_df, how='left')

# %%
weight_df.head(10)
# Out:
#       id    weight        name    patronymic       surname
# 0  27403  4.105632      Максим    Михайлович         Руссо
# 1   4270  3.978506  Александра  Владимировна        Брутер
# 2  28751  3.952230        Иван    Николаевич       Семушин
# 3  30152  3.775838       Артём     Сергеевич      Сорожкин
# 4  27822  3.770671      Михаил  Владимирович     Савченков
# 5  30270  3.767216      Сергей    Леонидович       Спешков
# 6  20691  3.624435   Станислав   Григорьевич   Мереминский
# 7  18036  3.622061      Михаил         Ильич  Левандовский
# 8  26089  3.580913       Ирина     Сергеевна    Прокофьева
# 9  22799  3.572561      Сергей      Игоревич     Николенко

# %% [markdown]
# ## Оценка качества

# %%
test_df_ = final_df[final_df['dateStart'].dt.year==2020]

# %% [markdown]
# Создаем отображение из ID игрока на его рейтинг.

# %%
mapping = dict()
for idx, row in weight_df.iterrows():
    mapping[row['id']] = row['weight']

# %% [markdown]
# В качестве самого простой статистики для оценки рейтинга можно взять сумму всех рейтингов игроков, умноженную на -1 (чем выше рейтинг, тем ниже номер в рейтинговой таблице).

# %%
test_df_['team_rating'] = test_df_['playerIDs'].apply(lambda row: -sum(mapping.get(id_, logreg.intercept_[0]) for id_ in row))
# Out:
# C:\Users\nickp\AppData\Local\Temp\ipykernel_8484\4025077547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_['team_rating'] = test_df_['playerIDs'].apply(lambda row: -sum(mapping.get(id_, logreg.intercept_[0]) for id_ in row))

# %% [markdown]
# Отсортируем значения

# %%
test_df_.sort_values(by=['id', 'position'], inplace=True)
# Out:
# C:\Users\nickp\AppData\Local\Temp\ipykernel_8484\3152601698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df_.sort_values(by=['id', 'position'], inplace=True)

# %%
test_df_.groupby('id').apply(lambda group: spearmanr(group['position'], group['team_rating'])[0]).mean()
# Out:
# 0.7907635288779833

# %%
test_df_.groupby('id').apply(lambda group: kendalltau(group['position'], group['team_rating'])[0]).mean()
# Out:
# 0.6306975038260684

# %% [markdown]
# Таким образом, достаточно простая модель, выдает 0,79 по корреляции Спирмана и 0,63 по корреляции Кендалла, что вполне себе неплохой результат.

# %% [markdown]
# ## Рейтинг-лист турниров

# %%
question_df = pd.DataFrame({'question_id': ohe.categories_[1], 'weight': logreg.coef_[0][len(ohe.categories_[0]):]}).sort_values(by='weight', ascending=False)

# %% [markdown]
# Рейтинг у вопросов обратный, так как больший вес приводит к большей вероятности на него ответить, верно также обратное.

# %%
question_df.tail(10)
# Out:
#       question_id    weight
# 21746      5795_8 -5.340594
# 21734     5795_50 -5.340594
# 21726     5795_43 -5.340595
# 20827      5774_6 -5.360813
# 21085     5780_11 -5.506795
# 1763      5159_34 -5.540932
# 1735       5159_0 -5.540934
# 8391      5465_67 -5.579494
# 8360      5465_39 -5.579495
# 2023      5186_17 -5.711728

# %% [markdown]
# Из рейтинга топ-10 вопросов 2019-го года удалось найти следующие:
# * [Первенство правого полушария, вопрос 35](https://db.chgk.info/node/8307)
# * [Первенство правого полушария, вопрос 1](https://db.chgk.info/node/8307)
# * [Кубок ярмарок, вопрос 12](https://db.chgk.info/node/8070)
# * [Кубок Москвы, вопрос 8](https://db.chgk.info/node/8376)
# * [Кубок Москвы, вопрос 9](https://db.chgk.info/node/8376)
# * [Кубок Москвы, вопрос 44](https://db.chgk.info/node/8376)
# * [Кубок Москвы, вопрос 51](https://db.chgk.info/node/8376)

# %%
question_df['id'] = question_df['question_id'].str.split('_').str[0]

# %%
tour_rating_df = question_df.groupby('id', as_index=False)['weight'].sum()

# %%
tour_rating_df['id'] = tour_rating_df['id'].astype(int)

# %%
tournaments_df['id'] = tournaments_df['id'].astype(int)

# %%
tournaments_df.head()
# Out:
#    id                                name                  dateStart  \
# 1   1            Чемпионат Южного Кавказа  2003-07-25T00:00:00+04:00
# 2   2                         Летние зори  2003-08-09T00:00:00+04:00
# 3   3                    Турнир в Ижевске  2003-11-22T00:00:00+03:00
# 4   4  Чемпионат Украины. Переходной этап  2003-10-11T00:00:00+04:00
# 5   5                 Бостонское чаепитие  2003-10-10T00:00:00+04:00
#
#                      dateEnd                          type      season  \
# 1  2003-07-27T00:00:00+04:00  {'id': 2, 'name': 'Обычный'}  /seasons/1
# 2  2003-08-09T00:00:00+04:00  {'id': 2, 'name': 'Обычный'}  /seasons/1
# 3  2003-11-24T00:00:00+03:00  {'id': 2, 'name': 'Обычный'}  /seasons/2
# 4  2003-10-12T00:00:00+04:00  {'id': 2, 'name': 'Обычный'}  /seasons/2
# 5  2003-10-13T00:00:00+04:00  {'id': 2, 'name': 'Обычный'}  /seasons/2
#
#   orgcommittee synchData questionQty
# 1           []      None        None
# 2           []      None        None
# 3           []      None        None
# 4           []      None        None
# 5           []      None        None

# %%
tour_rating_df.merge(tournaments_df[['id', 'name']], on='id').sort_values(by='weight')
# Out:
#        id      weight                                     name
# 665  6149 -800.431321  Чемпионат Санкт-Петербурга. Первая лига
# 666  6150 -202.673013  Чемпионат Санкт-Петербурга. Высшая лига
# 179  5465 -139.270284                         Чемпионат России
# 632  6085 -133.496634              Серия Гран-при. Общий зачёт
# 543  5928 -103.008129                              Угрюмый Ёрш
# ..    ...         ...                                      ...
# 637  6090  133.668571                      Дзержинский марафон
# 289  5592  144.105423                     Студенческая лига ЧТ
# 469  5827  323.016336        Шестой киевский марафон. Асинхрон
# 674  6249  410.151888           Школьный синхрон-lite. Сезон 3
# 675  6254  433.961549                            Школьная лига
#
# [677 rows x 3 columns]

# %% [markdown]
# Удивительно, что Чемпионаты Санкт-Петербурга так далеко отстоят от остальных турниров. Сложно пока сказать, есть ли этому численное объяснение. Возможно, имела бы смысл нормировка рейтинга, когда вместо суммы рейтингов стоило бы взять их среднее.

# %% [markdown]
# ## EM-алгоритм

# %% [markdown]
# В качестве скрытой переменной можно попробовать использовать вероятность того, что игрок ответил на вопрос при условии, что команда ответила на вопрос. Эту вероятность мы и будем пересчитывать на Е-шаге и использовать как целевую переменную при моделировании на M-шаге, например, с помощью логистической регрессии.

# %% [markdown]
# На Е-шаге будем нормировать переменные: если команда не ответила на вопрос, то соответствующие скрытые переменные зануляем; если ответила и значения скрытых переменных для команды равны $z_1, z_2, ..., z_k$, то новое значение будет равно: $$\tilde{z}_i=\frac{z_i}{1 - \prod_{j=1}^k(1-z_j)}$$

# %% [markdown]
# Так как надо будет учиться не на бинарной целевой переменной, нужно немного преобразовать логистическую регрессию.

# %%
class FractionalLogisticRegression(LogisticRegression):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.fitted = False
        
    def fit_(self, X, y, lr=1):
        if not self.fitted:
            super().fit(X, y)
            self.fitted = True
        X_transpose = X.T
        
        for i in range(self.max_iter):
            preds = self.predict_proba(X)[:, 1]
            grads = X_transpose @ (preds - y) / X.shape[0]
            
            self.coef_[0] -= lr * grads
            
            if i > 0 and i % 10 == 0:
                lr /= 2

# %%
flogreg = FractionalLogisticRegression(solver='saga', tol=0.05)

# %%
del test_df, final_df, players_df, tour_rating_df, tournaments_df, question_df, results_df, results, result, short_df, logreg

# %%
z = train_df['question_result']  # logreg.predict_proba(train_ohe)[:, 1]
n_iter = 10
for i in range(n_iter):
    print(f"Iter #{i}")
    # E-шаг. Обновляем значения скрытых переменных
    print("\tE-step")
    train_df['z'] = z
    train_df['comp_z'] = 1 - z
    train_df['team_score'] = 1 - train_df.groupby(['team.id', 'questionID'])['comp_z'].transform(np.prod)
    z = np.where(train_df['question_result'] == 0, 1e-5, train_df['z'] / train_df['team_score'])
    
    # M-шаг
    print("\tM-step")
    flogreg.fit_(train_ohe, z)
    z = flogreg.predict_proba(train_ohe)[:, 1]
    
    # Оценка модели
    weight_df = pd.DataFrame(
        {
            'id': ohe.categories_[0], 
            'weight': flogreg.coef_[0][:len(ohe.categories_[0])]
        }
    ).sort_values(by='weight', ascending=False)
    mapping = dict()
    for idx, row in weight_df.iterrows():
        mapping[row['id']] = row['weight']
    test_df_['team_rating'] = test_df_['playerIDs'].apply(lambda row: -sum(mapping.get(id_, flogreg.intercept_[0]) for id_ in row))
    test_df_.sort_values(by=['id', 'position'], inplace=True)
    print(f"\tSpearman corr: {test_df_.groupby('id').apply(lambda group: spearmanr(group['position'], group['team_rating'])[0]).mean():.4f}")
    print(f"\tKendall corr: {test_df_.groupby('id').apply(lambda group: kendalltau(group['position'], group['team_rating'])[0]).mean():.4f}")
# Out:
# Iter #0
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6306
# Iter #1
# 	E-step
# 	M-step
# 	Spearman corr: 0.7907
# 	Kendall corr: 0.6306
# Iter #2
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6306
# Iter #3
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6306
# Iter #4
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6306
# Iter #5
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6306
# Iter #6
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6306
# Iter #7
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6305
# Iter #8
# 	E-step
# 	M-step
# 	Spearman corr: 0.7906
# 	Kendall corr: 0.6305
# Iter #9
# 	E-step
# 	M-step
# 	Spearman corr: 0.7896
# 	Kendall corr: 0.6298
